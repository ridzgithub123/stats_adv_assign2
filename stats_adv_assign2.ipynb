# %%
#Q1: What are the Probability Mass Function (PMF) and Probability Density Function (PDF)? Explain with
# an example.


Probability Mass Function (PMF):
The Probability Mass Function (PMF) is also called a probability function or frequency function which characterizes the distribution of a discrete random variable.
Let X be a discrete random variable of a function, then the probability mass function of a random variable X is given by

Px (x) = P( X=x ), For all x belongs to the range of X

It is noted that the probability function should fall on the condition :
Px (x) ≥ 0 and
∑xϵRange(x) Px (x) = 1

Here the Range(X) is a countable set and it can be written as { x1, x2, x3, ….}
This means that the random variable X takes the value x1, x2, x3, ….

For example, consider the random variable X that represents the number of heads obtained
when flipping a fair coin twice. X can take on the values 0, 1, 2. The probability that X will be equal to 1 is 0.52.
Thus, it can be said that the probability 
mass function of X evaluated at 1 will be 0.52.

Probability Density Function (PDF):
Probability Density Function is used for calculating the probabilities for continuous random variables. 
When the cumulative distribution function (CDF) is differentiated we get the probability density function (PDF).
Both functions are used to represent the probability distribution of a continuous random variable.

The probability density function is defined over a specific range.
By differentiating CDF we get PDF and by integrating the probability density function we can get the cumulative density function.

Necessary Conditions for PDF
Let X be the continuous random variable with probability density function f(x).
For a function to be valid probability function should satisfy below conditions.

f(x) ≥ 0, ∀ x ∈ R
f(x) should be piecewise continuous.
Integration(f(x)dx) = 1   
So, the PDF should be the non-negative and piecewise continuous function whose total value evaluates to 1.

Probability Density Function (PDF): The PDF is used to define the probability of a continuous random variable coming within a distinct range of values,
as opposed to taking on any one value. For example, let X be a continuous random variable and the probability density function pdf is given by f(x)
= x – 1 , 0 < x ≤ 5. To find the probability P (1 < x ≤ 2), we integrate the pdf f(x) = x – 1 with the limits 1 and 2.

This results in the probability P (1 < x ≤ 2) = 0.54.

# %%
Q2: What is Cumulative Density Function (CDF)? Explain with an example. Why CDF is used?

A cumulative density function (CDF) is a function that gives the probability that a random variable will take a value less than or equal to a certain number. 
The CDF is calculated by taking the integral of the probability density function (PDF) over a range of values.

The CDF is useful for determining the likelihood that a random observation taken from the population will be less than or equal to a particular value.
The CDF always ranges between 0 and 1.

For example, consider a continuous random variable X that represents the time a person waits for an elevator to arrive. Suppose the longest one would 
 need to wait for the elevator is 2 minutes, so that the possible values of X (in minutes) are given by the interval [0, 2].
If we wish to calculate the probability that a person waits less than 30 seconds (or 0.5 minutes) for the elevator to arrive, then we calculate the 
following probability using the CDF.

Let's consider an example of rolling a fair six-sided die. Suppose 
X represents the outcome of the die roll. The CDF of this random variable X can be calculated as follows:
For any value x less than 1,F(x)=P(X≤x)=0, because it's impossible to get a result less than 1 when rolling a standard die.
For x=1, F(x)=P(X≤1)= 1/6, because there is one outcome (rolling a 1) out of six possible outcomes that is less than or equal to 1.
For x=2, F(x)=P(X≤2)= 2/6 = 1/3, because there are two outcomes (rolling a 1 or 2) out of six possible outcomes that are less than or equal to 2.
Similarly, we can compute F(x) for other values of x.

Why CDF is Used?

Probability Assessment: The CDF allows us to assess the probability of a random variable falling within a certain range or being less than or equal to a specific value.

Comparison: It provides a convenient way to compare the probabilities of different outcomes or values of the random variable.

Statistical Analysis: CDFs are commonly used in statistical analysis, hypothesis testing, and modeling to understand the behavior and characteristics of random variables.

Decision Making: CDFs can be used in decision-making processes, such as risk assessment and setting thresholds or critical values.

# %%
#Q3: What are some examples of situations where the normal distribution might be used as a model?
#Explain how the parameters of the normal distribution relate to the shape of the distribution.

The normal distribution, also known as the Gaussian distribution, is one of the most widely used probability distributions in various fields due to its many desirable properties. Here are some examples of situations where the normal distribution might be used as a model:

Biological Measurements: Height and weight measurements of a population often follow a normal distribution.
Psychometric Tests: Test scores, such as IQ scores, often approximate a normal distribution.
Financial Data: Stock prices, returns on investments, and other financial data often exhibit a normal distribution.
Natural Phenomena: Various natural phenomena, such as the distribution of errors in scientific measurements, may be modeled using a normal distribution.
Manufacturing Processes: Characteristics of manufactured products, such as lengths or diameters, may be normally distributed.
Now, let's discuss how the parameters of the normal distribution relate to the shape of the distribution:

Mean (μ):
The mean determines the center or location of the distribution.
It is the point around which the data is symmetrically distributed.
Shifting the mean to the right or left will change the center of the distribution without altering its shape.
If the mean is increased, the distribution will shift to the right, and if it is decreased, the distribution will shift to the left.

Standard Deviation (σ):
The standard deviation determines the spread or dispersion of the distribution.
A larger standard deviation indicates that the data points are more spread out from the mean, resulting in a wider distribution.
Conversely, a smaller standard deviation indicates that the data points are clustered closer to the mean, resulting in a narrower distribution.
Changing the standard deviation will affect the width of the distribution without changing its center.

Variance (σ^2):
The variance is the square of the standard deviation and represents the average squared deviation from the mean.
It provides a measure of the spread of the distribution similar to the standard deviation.
Increasing the variance will result in a wider distribution, and decreasing it will result in a narrower distribution.

# %%
#Q4: Explain the importance of Normal Distribution. Give a few real-life examples of Normal
#Distribution.

The normal distribution, also known as the Gaussian distribution, is one of the most important and widely used probability distributions in statistics and probability theory. Its importance stems from several key characteristics:

Ubiquitous Nature: The normal distribution arises naturally in many real-world phenomena. 
It is often observed in various fields such as science, engineering, finance, social sciences, and more. 
Many natural processes tend to produce data that follow a normal distribution, making it a fundamental concept in modeling and analysis.

Central Limit Theorem: The normal distribution plays a central role in the Central Limit Theorem (CLT), which states that the distribution of the sum (or average) of a large number of independent and identically distributed random variables approaches a normal distribution, regardless of the original distribution of the variables.
This property makes the normal distribution indispensable in statistical inference and hypothesis testing.

Mathematical Properties: The normal distribution has well-defined mathematical properties, which make it analytically tractable and convenient for mathematical manipulation. 
It allows for straightforward calculation of probabilities, percentiles, and other statistical measures.

Parameterization: The normal distribution is characterized by two parameters: the mean (μ) and the standard deviation (σ). 
These parameters determine the shape, location, and spread of the distribution, providing a flexible framework for modeling various data sets.

Real-life examples of phenomena that can be modeled using the normal distribution include:

Height and Weight: Human heights and weights often follow a normal distribution within a population. 
For example, heights of adult males or females in a given region may approximately follow a normal distribution.

IQ Scores: Intelligence quotient (IQ) scores from standardized tests, such as the Wechsler Adult Intelligence Scale (WAIS), are typically designed to have a normal distribution with a mean of 100 and a standard deviation of 15.

Measurement Errors: Errors in scientific measurements, such as experimental data or instrument readings, are often normally distributed around the true value due to various factors like random errors and experimental uncertainties.

Financial Data: Returns on investments, stock prices, and other financial variables often exhibit a distribution that approximates a normal distribution. This assumption is foundational in many financial models and analyses.

Test Scores: Scores on standardized tests, such as SAT or GRE exams, are often designed to have a normal distribution to facilitate comparisons and evaluations of performance.

These examples illustrate the wide applicability and importance of the normal distribution in various domains, highlighting its role as a fundamental tool in statistical modeling, analysis, and inference.

# %%
#Q5: What is Bernaulli Distribution? Give an Example. What is the difference between Bernoulli
#Distribution and Binomial Distribution?

The Bernoulli distribution is a discrete probability distribution that represents the outcome of a single Bernoulli trial,
which is an experiment with two possible outcomes: success (usually denoted by 1) or failure (usually denoted by 0).
It is named after Swiss mathematician Jacob Bernoulli.

Probability Mass Function (PMF) of Bernoulli distribution:P(X=x)={ p        if x=1
                                                                 { q=1−p    if x=0

Where:
p is the probability of success,
q is the probability of failure (q=1−p).
Example of Bernoulli distribution:
Consider a single toss of a biased coin where the probability of getting a head (success) is p=0.6. 
Here, the outcome of the trial (1 for head, 0 for tail) follows a Bernoulli distribution.

Difference between Bernoulli Distribution and Binomial Distribution:

Number of Trials:
Bernoulli Distribution: It represents the outcome of a single Bernoulli trial, i.e., a single experiment with two possible outcomes.
Binomial Distribution: It represents the number of successes in a fixed number of independent Bernoulli trials.
                                                                  
Nature:
Bernoulli Distribution: It is used to model a single trial with two possible outcomes.
Binomial Distribution: It is used to model the number of successes in multiple independent trials.
                                                                  
Parameters:
Bernoulli Distribution: It has a single parameter p, representing the probability of success in a single trial.
Binomial Distribution: It has two parameters: 
n (the number of trials) and 
p (the probability of success in each trial).
                                                                  
Outcome:
Bernoulli Distribution: The outcome is a single binary value (0 or 1), representing failure or success in a single trial.
Binomial Distribution: The outcome is the count of successes in n independent Bernoulli trials.
                                                                  
PMF vs. Probability Mass Function (PMF):
Bernoulli Distribution: It has a simple PMF with only two possible outcomes.
Binomial Distribution: It has a more complex PMF that describes the probabilities of different numbers of successes in n trials.
                                                                  
In summary, the Bernoulli distribution is used to model a single trial with two outcomes,
 while the binomial distribution extends this concept to model the number of successes in a fixed number of independent trials.

# %%
#Q6. Consider a dataset with a mean of 50 and a standard deviation of 10. If we assume that the dataset
#is normally distributed, what is the probability that a randomly selected observation will be greater
#than 60? Use the appropriate formula and show your calculations.

To find the probability that a randomly selected observation from a normally distributed dataset with a mean of 50 and 
a standard deviation of 10 will be greater than 60,
we need to calculate the area under the normal distribution curve to the right of x=60.

We can use the standard normal distribution (with mean = 0 and standard deviation = 1) to calculate probabilities.
First, we need to standardize the value x=60 using the formula:
z = (x−μ)/σ
where:
x is the value we want to standardize (60),
μ is the mean of the distribution (50),
σ is the standard deviation of the distribution (10).
Putting in the values:
z= 60-50 / 10
z=1

Now, we need to find the probability P(Z>1) where 
Z follows the standard normal distribution. 

From the standard normal distribution table , we find thatP(Z>1) is approximately 0.1587.

Therefore, the probability that a randomly selected observation from the given dataset will be greater than 60 is approximately 0.1587.

# %%
Q7: Explain uniform Distribution with an example.

Uniform distribution is a probability distribution in which all outcomes have an equal chance of happening. 
For example, when you flip a coin, there is a 50% chance the flip is heads and a 50% chance it's tails, making it an example of uniform distribution. 
Rolling a single die is another example of uniform distribution, since each number is equally likely to occur.
A deck of cards also has uniform distributions within it since the probability of drawing a heart, club, diamond or spade is equally possible.

# %%
Q8: What is the z score? State the importance of the z score.

The z-score, also known as a standard score, is a numerical measurement used in statistics to describe a value’s relationship to the mean of a group of 
values. It is measured in terms of standard deviations from the mean. The z-score is positive if the value lies above the mean and negative if
it lies below the mean. The formula for calculating a z-score is:'''

z=x-μ/σ

 Where:

 x is the raw score,

 μ is the population mean, and

σ is the population standard deviation.
The importance of z-scores lies in their ability to provide several benefits:

1.Understand where a data point fits into a distribution: Z-scores help you understand where a specific observation falls within a distribution.

# 2.Compare observations between dissimilar variables: They allow for the comparison of scores from different data sets by standardizing the scores.

# 3.Identify outliers: Z-scores can help identify outliers in a data set.

# 4.Calculate probabilities and percentiles using the standard normal distribution: It allows researchers to calculate the probability of a score 
occurring within a standard normal distribution

# %%
Q9: What is Central Limit Theorem? State the significance of the Central Limit Theorem.

The Central Limit Theorem (CLT) is a fundamental concept in probability theory and statistics. It states that if you take sufficiently large samples
from a population with a finite level of variance, the mean of all samples from that population will be roughly equal to the population mean. This
holds true regardless of whether the population has a normal, Poisson, binomial, or any other distribution.

The CLT is significant for several reasons:

 1.Simplification: The CLT allows you to simplify problems in statistics by allowing you to work with a distribution that is approximately norma.

 2.Hypothesis Testing: The CLT is a crucial pillar of statistics and machine learning. It is at the heart of hypothesis testing.

 3.Large Data Handling: The CLT provides a practical way to analyze large data sets. Even if the data is extremely large, the CLT allows for the calculation
of approximate averages.

 4.Polling and Census: The CLT has applications in fields like election polling and census data calculation. It helps in estimating the number of people who
support a specific candidate or calculating various population details.

 5.Assumption of Normality: Many practices in statistics, such as those involving hypothesis testing or confidence intervals, make some assumptions concerning
the population that the data was obtained from. One assumption that is initially made in a statistics course is that the populations that we work with 
are normally distributed. The assumption that data is from a normal distribution simplifies matters but seems a little unrealistic. The CLT allows us to
get around the problem of data from a population that is not normal.

# %%
Q10: State the assumptions of the Central Limit Theorem.

The Central Limit Theorem (CLT) is based on the following assumptions:

 1.Random Sampling: The sample should be drawn randomly, following the condition of randomization.

 2.Independence: The samples drawn should be independent of each other. They should not influence the other samples.

 3.Sample Size: When the sampling is done without replacement, the sample size shouldn’t exceed 10% of the total population.

 4.Large Sample Size: The sample size should be sufficiently large. Often, a sample size of 30 or more is considered large enough for the CLT to hold.

 5.Finite Variance: The population from which the samples are drawn should have a finite variance.

These assumptions ensure that the sampling distribution of the sample means will approximate a normal distribution, regardless of the shape of the population distribution.
